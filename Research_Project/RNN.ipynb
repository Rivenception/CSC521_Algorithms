# %% [markdown]
# <a href="https://colab.research.google.com/github/Rivenception/CSC521_Algorithms/blob/main/Research_Project/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data source
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

all_pollution_data = pd.read_csv("/content/drive/My Drive/Taiwain_2009_2011.csv")

#show the first 5 rows of DataFrame
all_pollution_data.head()

# Reducing our dataset to PM2.5 column only (single column)
pollution_pm25 = all_pollution_data[['PM2.5']].values

print(pollution_pm25.shape)
# Output is (1095, 1) which is 1095 records in the dataset.

all_pollution_data.columns

# module to help transform data to a range between 0 and 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

pollution_pm25_scaled = scaler.fit_transform(pollution_pm25)

pollution_pm25_scaled

num_of_records = len(pollution_pm25_scaled)

# Create the training and test sets from pollution_pm25_scaled
pollution_pm25_features= []
pollution_pm25_labels = []
for i in range (10, (num_of_records)):
  pollution_pm25_features.append(pollution_pm25_scaled[i-10: i, 0])
  pollution_pm25_labels.append(pollution_pm25_scaled [i, 0])

x_train = np.array(pollution_pm25_features[0:100])
# Output as (100, 10) which means the x_train array is 2 dimensions of 100 rows and 10 columns

y_train = np.array(pollution_pm25_labels[0:100])
# Output as (100,) which means the y_train array is one dimensions and 100 rows

# print(x_train.shape)
# print(y_train.shape)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# print(x_train.shape)

# print(x_train[(0):(2)])

x_test = np.array(pollution_pm25_features[101:])
y_test = np.array(pollution_pm25_labels[101:])

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# print(x_test.shape)
# print(y_test.shape)

# Creating the Neural Network
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM
from tensorflow.keras.models import Model

input_layer = Input(shape = (x_train.shape[1],1))
lstm1=LSTM(120,activation='tanh',return_sequences=True)(input_layer)
dropout1=Dropout(0.1)(lstm1)
lstm2=LSTM(100,activation='tanh',return_sequences=True)(dropout1)
lstm3=LSTM(80,activation='tanh',return_sequences=True)(lstm2)
lstm4=LSTM(50,activation='tanh')(lstm3)
output_layer=Dense(1,activation='linear')(lstm4)
model=Model(input_layer,output_layer)
model.compile(optimizer="adam", loss="mse")

print(model.summary())

# print(x_train.shape)
# print(y_train.shape)

model_history = model.fit(x_train, y_train, batch_size=20, epochs=100, validation_data=(x_test, y_test), verbose=1,)

y_pred = model.predict(x_test)
# print(y_pred.shape)

y_pred = scaler.inverse_transform(y_pred)

# print(y_pred)
# print(y_test.shape)

y_test = y_test.reshape(-1,1)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))

# print(y_test)

# Plot the data with matlib
plt.figure(figsize=(15,5))
plt.plot(y_test, color = 'red', label = 'Real PM2.5')
plt.plot(y_pred, color = 'blue', label = 'Predicted PM2.5')
plt.title('PM2.5 Prediction')
plt.xlabel('Time')
plt.ylabel('PM2.5')
plt.legend()
plt.show()

# Prediction Method for an input data set
new_array=np.array([17.06, 11.25, 29.92, 26.04, 19.96, 12.88, 16.9, 14.21, 17.5, 13.63])

new_array=new_array.reshape(-1, 1)

# print(new_array)
# print(new_array.shape)

new_array_scaled=scaler.fit_transform(new_array)

new_array_scaled=np.reshape(new_array_scaled, (1, 10, 1))

# print(new_array_scaled.shape)
# print(new_array_scaled)

new_pred=model.predict(new_array_scaled)

new_pred=scaler.inverse_transform(new_pred)

# print(new_pred.shape)

new_pred=scaler.inverse_transform(new_pred)

print('"We predict the PM2.5 whill be:')
print(*new_pred[0])
# Out:
# (1095, 1)
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, 10, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_16 (LSTM)                       │ (None, 10, 120)             │          58,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 10, 120)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_17 (LSTM)                       │ (None, 10, 100)             │          88,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_18 (LSTM)                       │ (None, 10, 80)              │          57,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_19 (LSTM)                       │ (None, 50)                  │          26,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,131 (902.86 KB)
#  Trainable params: 231,131 (902.86 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - loss: 0.0399 - val_loss: 0.0116
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0171 - val_loss: 0.0119
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0161 - val_loss: 0.0131
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0172 - val_loss: 0.0116
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - loss: 0.0152 - val_loss: 0.0127
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.0138 - val_loss: 0.0120
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0145 - val_loss: 0.0117
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.0162 - val_loss: 0.0117
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0141 - val_loss: 0.0118
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0139 - val_loss: 0.0121
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0143 - val_loss: 0.0119
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0150 - val_loss: 0.0118
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0138 - val_loss: 0.0118
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0135 - val_loss: 0.0122
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0151 - val_loss: 0.0119
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0159 - val_loss: 0.0118
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0147 - val_loss: 0.0118
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0158 - val_loss: 0.0119
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0135 - val_loss: 0.0120
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0152 - val_loss: 0.0122
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0148 - val_loss: 0.0119
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0145 - val_loss: 0.0120
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0128 - val_loss: 0.0120
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0153 - val_loss: 0.0123
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.0142 - val_loss: 0.0120
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.0127 - val_loss: 0.0119
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 0.0146 - val_loss: 0.0123
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0150 - val_loss: 0.0122
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0166 - val_loss: 0.0121
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0152 - val_loss: 0.0120
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0152 - val_loss: 0.0120
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0119 - val_loss: 0.0121
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0136 - val_loss: 0.0125
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0144 - val_loss: 0.0122
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0155 - val_loss: 0.0121
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0135 - val_loss: 0.0122
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0158 - val_loss: 0.0125
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0164 - val_loss: 0.0121
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0121 - val_loss: 0.0121
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0134 - val_loss: 0.0125
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0138 - val_loss: 0.0129
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0175 - val_loss: 0.0123
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0136 - val_loss: 0.0120
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0149 - val_loss: 0.0121
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.0156 - val_loss: 0.0127
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.0154 - val_loss: 0.0122
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 0.0142 - val_loss: 0.0125
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0129 - val_loss: 0.0121
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0166 - val_loss: 0.0122
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0137 - val_loss: 0.0125
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0146 - val_loss: 0.0123
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0150 - val_loss: 0.0121
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0114 - val_loss: 0.0121
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0143 - val_loss: 0.0124
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0142 - val_loss: 0.0121
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0159 - val_loss: 0.0123
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0146 - val_loss: 0.0123
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0130 - val_loss: 0.0121
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0125 - val_loss: 0.0122
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0147 - val_loss: 0.0124
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0134 - val_loss: 0.0122
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0129 - val_loss: 0.0123
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0131 - val_loss: 0.0123
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0143 - val_loss: 0.0125
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.0162 - val_loss: 0.0122
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0121 - val_loss: 0.0121
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.0142 - val_loss: 0.0121
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.0145 - val_loss: 0.0121
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0157 - val_loss: 0.0127
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0146 - val_loss: 0.0122
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0140 - val_loss: 0.0120
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0134 - val_loss: 0.0119
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0154 - val_loss: 0.0124
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0150 - val_loss: 0.0118
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0136 - val_loss: 0.0117
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0118 - val_loss: 0.0122
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0141 - val_loss: 0.0118
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0147 - val_loss: 0.0112
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0136 - val_loss: 0.0110
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0129 - val_loss: 0.0108
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0121 - val_loss: 0.0107
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0137 - val_loss: 0.0109
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0138 - val_loss: 0.0104
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0129 - val_loss: 0.0107
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0120 - val_loss: 0.0108
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 0.0126 - val_loss: 0.0108
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.0122 - val_loss: 0.0099
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0130 - val_loss: 0.0100
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0127 - val_loss: 0.0097
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0134 - val_loss: 0.0096
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0104 - val_loss: 0.0095
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0117 - val_loss: 0.0099
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0116 - val_loss: 0.0097
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0148 - val_loss: 0.0096
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0101 - val_loss: 0.0096
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0116 - val_loss: 0.0092
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# "We predict the PM2.5 whill be:
# 272.44482
